# %% [markdown]
# ## Lab: 12 - Data Analysis with Pandas: Video Game Stats

# %% [markdown]
# Thomas Sherer, 2020-07-08

# %% [markdown]
# ### SETUP

# %%
import pandas as pd

# %%
vg_df = pd.read_csv('./assets/vgsales.csv')
vg_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# #### Q1: Which company is the most common video game publisher?

# %%
top_publisher = vg_df['Publisher'].mode()[0]
top_publisher
# Out:
# 'Electronic Arts'

# %% [markdown]
# #### Q2: What’s the most common platform?

# %%
top_platform = vg_df['Platform'].mode()[0]
top_platform
# Out:
# 'DS'

# %% [markdown]
# #### Q3: What about the most common genre?

# %%
top_genre = vg_df['Genre'].mode()[0]
top_genre
# Out:
# 'Action'

# %% [markdown]
# #### Q4: What are the top 20 highest grossing games?

# %%
top_20_grossing = vg_df[['Name', 'Global_Sales']].nlargest(20, ['Global_Sales'])
top_20_grossing
# Out:
#                                             Name  Global_Sales
# 0                                     Wii Sports         82.74
# 1                              Super Mario Bros.         40.24
# 2                                 Mario Kart Wii         35.82
# 3                              Wii Sports Resort         33.00
# 4                       Pokemon Red/Pokemon Blue         31.37
# 5                                         Tetris         30.26
# 6                          New Super Mario Bros.         30.01
# 7                                       Wii Play         29.02
# 8                      New Super Mario Bros. Wii         28.62
# 9                                      Duck Hunt         28.31
# 10                                    Nintendogs         24.76
# 11                                 Mario Kart DS         23.42
# 12                   Pokemon Gold/Pokemon Silver         23.10
# 13                                       Wii Fit         22.72
# ...

# %% [markdown]
# #### Q5: For North American video game sales, what’s the median?

# %%
na_median_sales = vg_df['NA_Sales'].median()
na_median_sales
# Out:
# 0.08

# %% [markdown]
# #### Q5a - Provide a secondary output showing ten games surrounding the median sales output
# - assume that games with same median value are sorted in descending order

# %%
na_median_subset = vg_df.loc[vg_df['NA_Sales'] == na_median_sales]
na_sales_median_middle = len(na_median_subset) // 2
na_median_games = na_median_subset[na_sales_median_middle-5:na_sales_median_middle+6]
na_median_games
# Out:
#         Rank                                Name Platform    Year  \
# 9931    9933            Spider-Man: Edge of Time      3DS  2011.0
# 9934    9936                    Turok: Evolution      GBA  2002.0
# 9957    9959                            Deadpool     XOne  2015.0
# 9996    9998          GT Advance 2: Rally Racing      GBA  2001.0
# 10000  10002                      A Witch's Tale       DS  2009.0
# 10012  10014                   Nickelodeon Dance     X360  2011.0
# 10020  10022            Phantasy Star Collection      GBA  2002.0
# 10022  10024               LEGO Knights' Kingdom      GBA  2004.0
# 10024  10026  Family Game Night 4: The Game Show      PS3  2011.0
# 10026  10028                        NBA Jam 2002      GBA  2002.0
# 10029  10031            Tony Hawk's Pro Skater 5     XOne  2015.0
#
#               Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 9931         Action             Activision      0.08      0.03      0.00
# ...

# %% [markdown]
# ##### Q6: For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
# Calculating NA Sales Mean:
na_sales_mean = vg_df['NA_Sales'].mean()
na_sales_mean
# Out:
# 0.26466742981082064
